# %%
from resonator_tools import circuit

# port1.GUIfit()

# %%
port1 = circuit.notch_port()
port1.myadd_froms2p(r'..\data\trap_test\drive_08_01_9am_fine.csv','S21',fdata_unit=1.0)
port1.autofit()
print("Fit results:", port1.fitresults)
port1.plotall()
print("single photon limit:", port1.get_single_photon_limit(diacorr=True), "dBm")
print("photons in reso for input -140dBm:", port1.get_photons_in_resonator(-140,unit='dBm',diacorr=True), "photons")
print("done")
# Out:
# Fit results: {'Qi_dia_corr': np.float64(118.53558874058382), 'Qi_no_corr': np.float64(155.05555189054112), 'absQc': np.float64(46.667806219649876), 'Qc_dia_corr': np.float64(51.43751197324514), 'Ql': np.float64(35.871415768103226), 'fr': np.float64(1446374100.242923), 'theta0': np.float64(-2.707545899206097), 'phi0': np.float64(0.4340455562852048), 'phi0_err': np.float64(0.006792669268149303), 'Ql_err': np.float64(0.2692057719521404), 'absQc_err': np.float64(0.2424667176191082), 'fr_err': np.float64(150972.67634717465), 'chi_square': np.float64(0.002012931034689435), 'Qi_no_corr_err': np.float64(3.6538172061389567), 'Qi_dia_corr_err': np.float64(2.1498934438738617)}
# single photon limit: -130.60279902409414 dBm
# photons in reso for input -140dBm: 0.11488938440010435 photons
# done

# %%
port1 = circuit.notch_port()
port1.myadd_froms2p(r'..\data\trap_test\vna-sweep_T1_300_T2_300_2025-07-24-10262.csv','S21',fdata_unit=1.0)
port1.autofit()
print("Fit results:", port1.fitresults)
port1.plotall()
print("single photon limit:", port1.get_single_photon_limit(diacorr=True), "dBm")
print("photons in reso for input -140dBm:", port1.get_photons_in_resonator(-140,unit='dBm',diacorr=True), "photons")
print("done")
# Out:
# c:\users\42158\documents\postdoc-projects\resonator_tools\resonator_tools\circlefit.py:148: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   x0 = spopt.fsolve(func, 0., fprime=d_func)
# Fit results: {'Qi_dia_corr': np.float64(142.2005239043371), 'Qi_no_corr': np.float64(162.2792100566603), 'absQc': np.float64(38.3549001792226), 'Qc_dia_corr': np.float64(39.679101119547596), 'Ql': np.float64(31.02265559713943), 'fr': np.float64(1452929072.2287467), 'theta0': np.float64(-2.8835144123425662), 'phi0': np.float64(0.2590754671690507), 'phi0_err': np.float64(0.013222466497930243), 'Ql_err': np.float64(0.608963403439563), 'absQc_err': np.float64(0.5877463124299727), 'fr_err': np.float64(437972.8841936376), 'chi_square': np.float64(0.012590545748612762), 'Qi_no_corr_err': np.float64(10.830023553994662), 'Qi_dia_corr_err': np.float64(8.401699968177777)}
# single photon limit: -130.4293138367024 dBm
# photons in reso for input -140dBm: 0.11039041948484314 photons
# done

# %%
port1 = circuit.notch_port()
port1.myadd_froms2p(r'..\data\trap_test\vna-sweep_T1_300_T2_300_2025-07-24-15420.csv','S21',fdata_unit=1.0)
port1.autofit()
print("Fit results:", port1.fitresults)
port1.plotall()
print("single photon limit:", port1.get_single_photon_limit(diacorr=True), "dBm")
print("photons in reso for input -140dBm:", port1.get_photons_in_resonator(-140,unit='dBm',diacorr=True), "photons")
print("done")
# Out:
# Fit results: {'Qi_dia_corr': np.float64(522.6058667733353), 'Qi_no_corr': np.float64(721.9210498115904), 'absQc': np.float64(42.263112685496004), 'Qc_dia_corr': np.float64(43.228287333919354), 'Ql': np.float64(39.92575634977929), 'fr': np.float64(1450945763.7181203), 'theta0': np.float64(-2.929882291775355), 'phi0': np.float64(0.21171192416826742), 'phi0_err': np.float64(0.022292008837229996), 'Ql_err': np.float64(1.2540926334853082), 'absQc_err': np.float64(1.2050718966179736), 'fr_err': np.float64(586787.1350807707), 'chi_square': np.float64(0.017350534828433295), 'Qi_no_corr_err': np.float64(238.73894396096532), 'Qi_dia_corr_err': np.float64(121.35682752457102)}
# single photon limit: -132.2606001059724 dBm
# photons in reso for input -140dBm: 0.16829065882069158 photons
# done

# %%
port1 = circuit.notch_port()
port1.myadd_froms2p(r'..\data\trap_test\vna-sweep_T1_300_T2_300_2025-07-24-16142.csv','S21',fdata_unit=1.0)
port1.autofit(fcrop=(1.4e9,1.5e9))
print("Fit results:", port1.fitresults)
port1.plotall()
print("single photon limit:", port1.get_single_photon_limit(diacorr=True), "dBm")
print("photons in reso for input -140dBm:", port1.get_photons_in_resonator(-140,unit='dBm',diacorr=True), "photons")
print("done")
# Out:
# c:\Users\42158\anaconda3\envs\nanoVNA\Lib\site-packages\resonator_tools-0.1-py3.13.egg\resonator_tools\circlefit.py:148: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Fit results: {'Qi_dia_corr': np.float64(-3.4807388292129926), 'Qi_no_corr': np.float64(-3.4369312071223406), 'absQc': np.float64(2.9666437306284523), 'Qc_dia_corr': np.float64(2.999226049998627), 'Ql': np.float64(21.6806760286828), 'fr': np.float64(1409345662.4286497), 'theta0': np.float64(4.568835390405832), 'phi0': np.float64(-0.14753509733424439), 'phi0_err': np.float64(0.1735570732947369), 'Ql_err': np.float64(5.940719816574947), 'absQc_err': np.float64(0.4980234695802095), 'fr_err': np.float64(3861273.3829587633), 'chi_square': np.float64(24.06529917773962), 'Qi_no_corr_err': np.float64(0.5309414129036408), 'Qi_dia_corr_err': np.float64(0.4897585387225604)}
# single photon limit: -138.7972548741244 dBm
# photons in reso for input -140dBm: 0.7580982383054956 photons
# done

# %% [markdown]
# ## S11

# %%
port1 = circuit.reflection_port()
port1.myadd_froms2p(r'..\data\trap_test\resonator_08_01_9am.csv','S11',fdata_unit=1.0)
port1.autofit()
print("Fit results:", port1.fitresults)
port1.plotall()
print("single photon limit:", port1.get_single_photon_limit(), "dBm")
print("photons in reso for input -140dBm:", port1.get_photons_in_resonator(-140,unit='dBm'), "photons")
print("done")
# Out:
# Fit results: {'Qi': np.float64(287.3265509569066), 'Qc': np.float64(323.8959315621283), 'Ql': np.float64(152.25863502464074), 'fr': np.float64(187908299.71374774), 'theta0': np.float64(-0.006721308746448413), 'Ql_err': np.float64(1.4571089078668515), 'Qc_err': np.float64(2.3317930453030113), 'fr_err': np.float64(3793.761179931029), 'chi_square': np.float64(0.0018106347888492656), 'Qi_err': np.float64(4.0238237781903194)}
# single photon limit: -152.89490539105276 dBm
# photons in reso for input -140dBm: 19.475586228599592 photons
# done

# %%
port1 = circuit.reflection_port()
port1.myadd_froms2p(r'..\data\trap_test\mounted_in_cryo_1_pin_measurement_with_trap.csv','S11',fdata_unit=1.0)
port1.autofit(fcrop=(0.21e9,0.27e9))
print("Fit results:", port1.fitresults)
port1.plotall()
print("single photon limit:", port1.get_single_photon_limit(), "dBm")
print("photons in reso for input -140dBm:", port1.get_photons_in_resonator(-140,unit='dBm'), "photons")
print("done")
# Out:
# Fit results: {'Qi': np.float64(222.7872172503792), 'Qc': np.float64(625.8970765193573), 'Ql': np.float64(164.30358024361928), 'fr': np.float64(226890611.06853166), 'theta0': np.float64(-0.19414895970107232), 'Ql_err': np.float64(3.3117127206132024), 'Qc_err': np.float64(8.51530339120565), 'fr_err': np.float64(10297.014448969821), 'chi_square': np.float64(0.005325572565258576), 'Qi_err': np.float64(5.281135478874958)}
# single photon limit: -149.05782174958352 dBm
# photons in reso for input -140dBm: 8.049745963141696 photons
# done

# %%
port1 = circuit.reflection_port()
port1.myadd_froms2p(r'..\data\trap_test\mounted_in_cryo_1_pin_measurement_calibrated.csv','S11',fdata_unit=1.0)
port1.autofit(fcrop=(0.2e9,0.25e9),electric_delay=0.0)
print("Fit results:", port1.fitresults)
port1.plotall()
print("single photon limit:", port1.get_single_photon_limit(), "dBm")
print("photons in reso for input -140dBm:", port1.get_photons_in_resonator(-140,unit='dBm'), "photons")
print("done")
# Out:
# Fit results: {'Qi': np.float64(243.89370921023254), 'Qc': np.float64(232.555642747335), 'Ql': np.float64(119.04488499014396), 'fr': np.float64(230140289.82818642), 'theta0': np.float64(-0.035288391437224835), 'Ql_err': np.float64(1.7113374367530902), 'Qc_err': np.float64(2.139778251051122), 'fr_err': np.float64(10021.801128092718), 'chi_square': np.float64(0.0015967723802452361), 'Qi_err': np.float64(5.984871896917188)}
# single photon limit: -150.4353337999192 dBm
# photons in reso for input -140dBm: 11.054354301853687 photons
# done
